# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.15

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="groq/compound-mini")
llm
# Out:
# ChatGroq(profile={}, client=<groq.resources.chat.completions.Completions object at 0x000001C013C597F0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001C013C58620>, model_name='groq/compound-mini', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %% [markdown]
# ### Generative AI Application using agents and groq/openai model

# %% [markdown]
# # First Generative AI Application

# %% [markdown]
# # LLM Model integration with google Gemini api

# %%
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model= init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("write me an essay on ai")
print(response.content)
# Out:
# ## The Dawn of the Algorithmic Age: Navigating the Transformative Power of Artificial Intelligence
#
# We stand at the precipice of a new era, one defined by the burgeoning capabilities of artificial intelligence (AI). No longer confined to the realm of science fiction, AI is rapidly weaving itself into the fabric of our daily lives, from the personalized recommendations that shape our consumption to the sophisticated algorithms that drive scientific discovery. This transformative technology, born from the ambition to imbue machines with human-like intelligence, promises unprecedented advancements, yet also presents profound ethical, societal, and existential questions that demand our careful consideration.
#
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model = "gemini-2.5-flash-lite")
response = model.invoke("write me an essay on cow in 10 lines")
print(response.content)
# Out:
# The gentle cow, a cornerstone of rural life,
# Grazes peacefully, her presence a calming sight.
# Her patient gaze, reflecting sunlit fields,
# Provides sustenance, from milk to hearty meals.
# A mother's care, in every moo she makes,
# Nurturing life, for goodness gracious sakes.
# Her slow, deliberate steps, a rhythmic sound,
# As she treads softly on the verdant ground.
# A symbol of abundance, calm, and grace,
# The humble cow holds a vital, cherished place.

# %% [markdown]
# # GROQ Model Integration

# %%
import os 
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"]= os.getenv("GROQ_API_KEY")
model = init_chat_model("groq:llama-3.1-8b-instant")
response = model.invoke("write me a joke on machine learing algorithms in hinglish")
print(response.content)
# Out:
# Ek machine learning engineer ne apne boss se kaha, "Sir, maine kuchh naya algorithm develop kiya hai jo machine learning ko bahut hi accha bana sakta hai."
#
# Boss ne poochha, "Kya hai yeh algorithm?"
#
# Machine learning engineer ne kaha, "Maine apna naam hi algorithm banaya hai, 'Sambhal Jao'."
#
# Boss ne poochha, "Sambhal Jao? Kya vahi karta hai?"
#
# Machine learning engineer ne kaha, "Haan, yeh tootne se pahle hi toot jaata hai."
#
# (Note: Hinglish is a mix of Hindi and English languages, with some words and phrases from both languages used together. In this joke, "Sambhal Jao" is a common Hindi phrase that means "be careful" or "mind it", but in this context, it's used as a name for an algorithm that fails before it can do anything.)

# %% [markdown]
# # Streaming and Batch
#  # Streaming
#  Streaming is crucial for enhancing the responsiveness of applications built on LLMs. By displaying output progressively, even before a complete response is ready,
#  streaming significantly improves user experience (UX), particularly when dealing with the latency of LLMs.

# %%
model.invoke("write 500 lines on developers")
# Out:
# AIMessage(content='**The World of Developers**\n\nDevelopers are the backbone of the modern technological world. They design, create, and maintain the software, applications, and systems that we use every day. Without them, our smartphones, computers, and other devices would be nothing more than expensive paperweights.\n\n**History of Developers**\n\nThe term "developer" has been around since the early days of computing. In the 1950s and 1960s, developers were known as programmers or coders. They wrote assembly language code to create the first computer programs. As technology advanced, so did the skills and tools of developers. Today, developers work with a wide range of programming languages, frameworks, and tools to create complex software systems.\n\n**Types of Developers**\n\nThere are many types of developers, each with their own specialization. Some of the most common types of developers include:\n\n1. **Web Developers**: They create websites, web applications, and mobile appl
# ...

# %%
for chunk in model.stream("write me 1000 lines on developers"):
   print(chunk.text, end= "", flush= True)
# Out:
# Here's a poem and a short story combined to describe the life of a developer.
#
# **The Developer's Journey**
#
# 1. In a world of code and machines so fine,
# A developer emerges, a hero divine.
# With a passion for programming, they take the stage,
# And bring to life the ideas that they engage.
#
# 2. Their journey begins with a single line,
# A simple script that sparks a creative shine.
# As they code and debug, their skills unfold,
# A masterpiece born, with logic to hold.
#
# 3. From beginner to pro, they climb the ranks,
# With each new project, their expertise expands in thanks.
# They learn and adapt, with every new test,
# And their creations grow, with each passing quest.
#
# 4. In the world of tech, they find their home,
# Where innovation meets, and progress is made known.
# With every line of code, they push the bound,
# And bring people closer, with each new found.
#
# 5. Developers work, through day and night,
# To bring their visions, to the digital light.
# ...

# %%
for chunk in model.stream("why do parrots have colourful feathers?"):
   print(chunk.text, end= "", flush= True)
# Out:
# Parrots have colorful feathers for several reasons:
#
# 1. **Mating and courtship**: Brightly colored feathers are often used as a way to attract a mate. Males will display their vibrant plumage to show off their health, genetic quality, and suitability as a mate. This is a common behavior in many bird species.
#
# 2. **Territorial display**: Parrots will also use their colorful feathers to mark their territory and warn off potential competitors. A brightly colored parrot can signal to other parrots that this is its territory, and it's not to be messed with.
#
# 3. **Social status**: In some parrot species, the color and quality of an individual's feathers can indicate its social status within the group. For example, dominant birds may have more vibrant or extensive coloration.
#
# ...

# %% [markdown]
# # Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content='Parrots have colorful feathers due to several reasons:\n\n1. **Attracting mates**: Males use their vibrant plumage to attract females and showcase their fitness, thereby increasing their chances of mating. The brighter the colors, the better chance of success in attracting a mate.\n\n2. **Territorial display**: Colorful feathers can serve as a signal to other parrots, warning them to stay away from a particular territory. This helps prevent conflicts and maintains social order within parrot communities.\n\n3. **Thermoregulation**: In some species, feathers with specific color patterns can help regulate body temperature. For example, black feathers can absorb heat, while white feathers reflect it.\n\n4. **Camouflage**: While it may seem counterintuitive, some parrots have color patterns that help them blend in with their environment, making it easier to hide from predators.\n\n5. **Evolutionary adaptation**: Parrots have evolved to thrive in various environments, and their co
# ...

# %%
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?",
    "write an essay on me",
    "write an essay on you"
]
, config={
    'max_concurrency':5,
}
)
for response in responses:
    print(response)
# Out:
# content='Parrots have colorful feathers due to several reasons:\n\n1. **Communication and Social Signaling**: Colorful feathers in parrots serve as an important means of communication and social signaling. Different species have unique color patterns that convey information about their age, sex, dominance status, and reproductive status. For example, some male parrots develop bright colors on their heads or necks during courtship or when establishing dominance.\n2. **Mate Attraction**: Bright colors are also used by male parrots to attract females. Males with more vibrant plumage are often more attractive to females, increasing their chances of mating and reproducing.\n3. **Warning and Self-Defense**: Colorful feathers can also serve as a warning to potential predators. Some parrots have bright colors that signal to predators that they are distasteful or toxic. This is known as "aposematic" coloration.\n4. **Identification and Recognition**: Each species of parrot has a unique color 
# ...
